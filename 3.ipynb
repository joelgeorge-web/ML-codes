# %%
from keras.datasets import cifar10
from keras.utils import to_categorical
from keras.layers import Flatten,Dense
from keras.models import Sequential

# %%
(x_train,y_train),(x_test,y_test) = cifar10.load_data()

# %%
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

y_train = to_categorical(y_train,10)
y_test = to_categorical(y_test,10)

# %%
model = Sequential()

model.add(Flatten(input_shape=(32,32,3)))
model.add(Dense(512,activation='relu',kernel_initializer='he_normal'))
model.add(Dense(256,activation='relu',kernel_initializer='he_normal'))
model.add(Dense(128,activation='relu',kernel_initializer='he_normal'))
model.add(Dense(10,activation='softmax',kernel_initializer='he_normal'))

model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
history = model.fit(x_train,y_train,epochs=10,validation_data=(x_test,y_test))
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 35s 22ms/step - loss: 1.8832 - accuracy: 0.3198 - val_loss: 1.7576 - val_accuracy: 0.3677
# Epoch 2/10
# 1563/1563 [==============================] - 33s 21ms/step - loss: 1.6873 - accuracy: 0.3905 - val_loss: 1.6566 - val_accuracy: 0.4102
# Epoch 3/10
# 1563/1563 [==============================] - 31s 20ms/step - loss: 1.6010 - accuracy: 0.4253 - val_loss: 1.5758 - val_accuracy: 0.4321
# Epoch 4/10
# 1563/1563 [==============================] - 31s 20ms/step - loss: 1.5423 - accuracy: 0.4471 - val_loss: 1.5625 - val_accuracy: 0.4465
# Epoch 5/10
# 1563/1563 [==============================] - 30s 19ms/step - loss: 1.5074 - accuracy: 0.4579 - val_loss: 1.4965 - val_accuracy: 0.4666
# Epoch 6/10
# 1563/1563 [==============================] - 30s 19ms/step - loss: 1.4722 - accuracy: 0.4712 - val_loss: 1.5621 - val_accuracy: 0.4396
# Epoch 7/10
# ...

# %%
model.evaluate(x_test,y_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 1.4532 - accuracy: 0.4856
# [1.4532133340835571, 0.48559999465942383]

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train','Test'],loc='upper left')
plt.show()

# %%
model1 = Sequential()

model1.add(Flatten(input_shape=(32,32,3)))
model1.add(Dense(512,activation='relu',kernel_initializer='glorot_uniform'))
model1.add(Dense(256,activation='relu',kernel_initializer='glorot_uniform'))
model1.add(Dense(128,activation='relu',kernel_initializer='glorot_uniform'))
model1.add(Dense(10,activation='softmax',kernel_initializer='glorot_uniform'))

model1.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
history1 = model1.fit(x_train,y_train,epochs=10,validation_data=(x_test,y_test))
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 32s 20ms/step - loss: 1.8546 - accuracy: 0.3272 - val_loss: 1.7242 - val_accuracy: 0.3754
# Epoch 2/10
# 1563/1563 [==============================] - 30s 19ms/step - loss: 1.6775 - accuracy: 0.3984 - val_loss: 1.6138 - val_accuracy: 0.4179
# Epoch 3/10
# 1563/1563 [==============================] - 30s 19ms/step - loss: 1.5883 - accuracy: 0.4311 - val_loss: 1.5542 - val_accuracy: 0.4399
# Epoch 4/10
# 1563/1563 [==============================] - 30s 19ms/step - loss: 1.5405 - accuracy: 0.4485 - val_loss: 1.5276 - val_accuracy: 0.4529
# Epoch 5/10
# 1563/1563 [==============================] - 30s 19ms/step - loss: 1.4956 - accuracy: 0.4636 - val_loss: 1.5302 - val_accuracy: 0.4536
# Epoch 6/10
# 1563/1563 [==============================] - 30s 19ms/step - loss: 1.4676 - accuracy: 0.4740 - val_loss: 1.4776 - val_accuracy: 0.4731
# Epoch 7/10
# ...

# %%
model1.evaluate(x_test,y_test)
# Out:
# 313/313 [==============================] - 2s 5ms/step - loss: 1.4595 - accuracy: 0.4854
# [1.4594690799713135, 0.48539999127388]

# %%
import matplotlib.pyplot as plt
plt.plot(history1.history['accuracy'])
plt.plot(history1.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train','Test'],loc='upper left')
plt.show()

# %%
#import sgd optimizer

from keras.optimizers import SGD

model2 = Sequential()

model2.add(Flatten(input_shape=(32,32,3)))
model2.add(Dense(512,activation='relu',kernel_initializer='he_normal'))
model2.add(Dense(256,activation='relu',kernel_initializer='he_normal'))
model2.add(Dense(128,activation='relu',kernel_initializer='he_normal'))
model2.add(Dense(10,activation='softmax',kernel_initializer='he_normal'))

model2.compile(loss='categorical_crossentropy',optimizer=SGD(lr=0.01,momentum=0.9),metrics=['accuracy'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       1 #import sgd optimizer
#       3 from keras.optimizers import SGD
# ----> 5 model2 = Sequential()
#       7 model2.add(Flatten(input_shape=(32,32,3)))
#       8 model2.add(Dense(512,activation='relu',kernel_initializer='he_normal'))
#
# NameError: name 'Sequential' is not defined
